# %% [markdown]
# <a href="https://colab.research.google.com/github/tannerunaveen4/hds5210-2023/blob/main/midterm/midterm_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HDS5210-2022 Midterm
#
# In the midterm, you're going to use all the programming and data management skills you've developed so far to build a risk calculator that pretends to be integrated with a clinical registry.  You'll compute the PRIEST COVID-19 Clinical Severity Score for a series of patients and, based on their risk of an adverse outcome, query a REST web service to find a hospital to transfer them to. The end result of your work will be a list of instructions on where each patient should be discharged given their risk and various characteristics of the patient.
#
# Each step in the midterm will build up to form your complete solution.
#
# **Make sure you write good docstrings and doctests along the way!!**
#
# **The midterm is due at 11:59 PM CST on Monday, October 23rd.**
#
# ---

# %% [markdown]
# ## Step 1: Calculate PRIEST Clinical Severity Score
#
# This scoring algorithm can be found [here on the MDCalc website](https://www.mdcalc.com/priest-covid-19-clinical-severity-score#evidence).
#
# 1. You will need to write a function called **priest()** with the following input parameters.
#  * Sex (Gender assigned at birth)
#  * Age in years
#  * Respiratory rate in breaths per minute
#  * Oxygen saturation as a percent between 0 and 1
#  * Heart rate in beats per minute
#  * Systolic BP in mmHg
#  * Temperature in degrees C
#  * Alertness as a string description
#  * Inspired Oxygen as as string description
#  * Performance Status as a string description
# 2. The function will need to follow the algorithm provided on the MDCalc website to compute a risk percentage that should be returned as a numeric value between 0 and 1.
# 3. Be sure to use docstring documentation and at least three built-in docstring test cases.
# 4. Assume that the input values that are strings could be any combination of upper or lower case. For example: 'male', 'Male', 'MALE', 'MalE' should all be interpretted by your code as male.
# 5. If any of the inputs are invalid (for example a sex value that is not recognizable as male or female) your code should return None.
#
# NOTES:
# 1. In the final step there is a table that translates from **PRIEST Score** to **30-day probability of an outcome** but the last two probabilities are shown as ranges (59-88% and >99%).  Our code needs to output a single number, however. For our code, use the following rule:
#  * If PRIEST score is between 17 and 25, the probability you return should be 0.59
#  * If PRIEST score is greater than or equal to 26, the probability you return should be 0.99

# %%
def priest(sex, age, respiratory_rate_per_minute, oxygen_saturation,
           heart_rate, systolic_BP,  temperature, alertness, inspired_oxygen, performance_status):
  """(str, int, float, float, int, float, float, str, str, str)->float
  Calculate PRIEST Clinical Severity Score.
  example:
  >>> priest('male', 50, 24, 0.80, 80, 120, 37, 'alert', 'room air', 'good')
  >>> priest('male', 50, 24, 0.80, 80, 120, 37, 'alert', 'air', 'unrestricted normal activity')
  0.22
  >>> priest('female', 66, 26, 0.90, 140, 80, 34, 'Confused or not alert', 'Supplemental oxygen', 'Bed/chair bound, no self-care')
  0.99
  >>> priest('female', 66, 26, 0.90, 140, 80, 34, 'Confused or not alert', 'Supplemental oxygen', 'Unrestricted normal activity')
  0.59
  >>> priest('female', 66, 26, 0.90, 140, 80, 34, 'Confused or not alert', 'Supplemental oxygenss', 'Unrestricted normal activity')
  """
  #Trensforming all the string input values lowercase
  sex = sex.lower()
  alert = alertness.lower()
  inspired_oxygen = inspired_oxygen.lower()
  performance_status = performance_status.lower()
  points = 0

  #checking if the input values are correct for sex case
  if sex not in ['male', 'female']:
    return None
  elif sex == 'female':
    points += 0
  elif sex == 'male':
    points += 1

  #checking for age case in it's categories
  if age >= 16 and age < 50 :
    points += 0
  elif age >= 50 and age < 66:
    points += 2
  elif age >= 66 and age <= 80 :
    points += 3
  elif age > 80:
    points += 4


  #checking for respiratory respiratory rate in breaths per minute
  if respiratory_rate_per_minute < 9:
    points += 3
  elif respiratory_rate_per_minute >= 9 and respiratory_rate_per_minute < 12:
    points += 1
  elif respiratory_rate_per_minute >= 12 and respiratory_rate_per_minute < 21:
    points += 0
  elif respiratory_rate_per_minute >= 21 and respiratory_rate_per_minute <= 24:
    points += 2
  elif respiratory_rate_per_minute > 24:
    points += 3


  #Oxygen saturation as a percent between 0 and 1
  if oxygen_saturation > (95 / 100):
    points += 0
  elif oxygen_saturation >= (94 / 100) and oxygen_saturation <= (95 / 100):
    points += 1
  elif oxygen_saturation >= (92 / 100) and oxygen_saturation < (94 / 100):
    points += 2
  elif oxygen_saturation < (92 / 100):
    points += 3


  # Heart rate in beats per minute
  if heart_rate < 41:
    points += 3
  elif heart_rate >= 41 and heart_rate < 51:
    points += 1
  elif heart_rate >= 51 and heart_rate < 91:
    points += 0
  elif heart_rate >= 91 and heart_rate < 111:
    points += 1
  elif heart_rate >= 111 and heart_rate <= 130:
    points += 2
  elif heart_rate > 130:
    points += 3


  #Systolic BP in mmHg
  if systolic_BP  < 91:
    points += 3
  elif systolic_BP >= 91 and systolic_BP < 101:
    points += 2
  elif systolic_BP >= 101 and systolic_BP < 111:
    points += 1
  elif systolic_BP >= 111 and systolic_BP <= 219:
    points += 0
  elif systolic_BP > 219:
    points += 3


  #Temperature in C
  if temperature < 35.1:
    points += 3
  elif temperature >= 35.1 and temperature < 36.1:
    points += 1
  elif temperature >= 36.1 and temperature < 38.1:
    points += 0
  elif temperature >= 38.1 and temperature <= 39.0:
    points += 1
  elif temperature > 39.0:
    points += 2


  #Alertness as a string description
  if alert not in ['alert', 'confused or not alert']:
    return None
  elif alert == 'alert':
    points += 0
  elif alert == 'confused or not alert':
    points += 3

  #Inspired Oxygen as as string description
  if inspired_oxygen not in ['air', 'supplemental oxygen']:
    return None
  elif inspired_oxygen == 'air':
    points += 0
  elif inspired_oxygen == 'supplemental oxygen':
    points += 2

  #Performance Status as a string description
  if performance_status not in ['unrestricted normal activity', 'limited strenuous activity, can do light activity',
                                'limited activity, can self-care', 'limited self-care', 'bed/chair bound, no self-care']:
    return None
  elif performance_status == 'unrestricted normal activity':
    points += 0
  elif performance_status == 'limited strenuous activity, can do light activity':
    points += 1
  elif performance_status == 'limited activity, can self-care':
    points += 2
  elif performance_status == 'limited self-care':
    points += 3
  elif performance_status == 'bed/chair bound, no self-care':
    points += 4

  #returning the pobability based on the rule provided above
  if points >= 0 and points < 2:
    return (1/100)
  elif points >= 2 and points < 4:
    return (2/100)
  elif points == 4:
    return (3/100)
  elif points == 5:
    return (9/100)
  elif points == 6:
    return (15/100)
  elif points == 7:
    return (18/100)
  elif points == 8:
    return (22/100)
  elif points == 9:
    return (26/100)
  elif points == 10:
    return (29/100)
  elif points == 11:
    return (34/100)
  elif points == 12:
    return (38/100)
  elif points == 13:
    return (46/100)
  elif points == 14:
    return (47/100)
  elif points == 15:
    return (49/100)
  elif points == 16:
    return (55/100)
  elif points >= 17 and points < 26:
    return 0.59
  elif points >= 26:
    return 0.99

# %%
print(priest('male', 50, 24, 0.80, 80, 120, 37, 'alert', 'room air', 'good'))
# Out:
# None

# %%
print(priest('male', 50, 24, 0.80, 80, 120, 37, 'alert', 'air', 'unrestricted normal activity'))
# Out:
# 0.22

# %%
print(priest('male', 50, 24, 0.80, 80, 120, 37, 'confused or not alert', 'air', 'bed/chair bound, no self-care'))
# Out:
# 0.49

# %%
print(priest('male', 50, 24, 0.80, 80, 120, 39.0, 'confused or not alert', 'air', 'bed/chair bound, no self-care'))
# Out:
# 0.55

# %%
import doctest
doctest.run_docstring_examples(priest, globals(),verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     priest('male', 50, 24, 0.80, 80, 120, 37, 'alert', 'room air', 'good')
# Expecting nothing
# ok
# Trying:
#     priest('male', 50, 24, 0.80, 80, 120, 37, 'alert', 'air', 'unrestricted normal activity')
# Expecting:
#     0.22
# ok
# Trying:
#     priest('female', 66, 26, 0.90, 140, 80, 34, 'Confused or not alert', 'Supplemental oxygen', 'Bed/chair bound, no self-care')
# Expecting:
#     0.99
# ok
# Trying:
#     priest('female', 66, 26, 0.90, 140, 80, 34, 'Confused or not alert', 'Supplemental oxygen', 'Unrestricted normal activity')
# Expecting:
#     0.59
# ok
# Trying:
#     priest('female', 66, 26, 0.90, 140, 80, 34, 'Confused or not alert', 'Supplemental oxygenss', 'Unrestricted normal activity')
# Expecting nothing
# ok

# %% [markdown]
# ## Part 2: Find a hospital
#
# The next thing we have to do is figure out where to send this particular patient.  The guidelines on where to send a patient are based on their age (pediatric, adult, geriatric), sex, and risk percentage.  Luckily, you don't have to implement these rules. I already have. All you have to do is use a REST web service that I've created for you.
#
# You'll want to use Python to make a call to my REST web service similar to the example URL below. The first part of the URL will be the same for everyone and every request that you make. What you will need to modify for each of your requests is the information after the question mark.
#
# ```
# https://oumdj6oci2.execute-api.us-east-1.amazonaws.com/prd/?age=40&sex=male&risk_pct=0.1
# ```
#
# The example above asks my web service where a 40-year old male with a risk of 10% should go.  What the web service will return back is a JSON string containing the information you need.  That JSON will look like this:
#
# ```json
# {
#   "age": "40",
#   "sex": "male",
#   "risk": "0.1",
#   "hospital": "Southwest Hospital and Medical Center"
# }
# ```
#
# My function is not smart enough to understand `'MALE'` is the same as `'male'`.  You have to send it exactly `'male'` or `'female'`
#
# 1. Your job is to write a function called **find_hospital()** that takes age, sex, and risk as parameters.
# 2. Your function should call this REST web service using the `requests` module
# 3. Then your function will need to interpret the JSON it gets and return just the name of the hospital
# 4. If anything fails, return None
# 5. Include a good docstring with at least three test cases.

# %%
import requests as req
#understing the json file the url returns.
url = "https://oumdj6oci2.execute-api.us-east-1.amazonaws.com/prd/?age=40&sex=male&risk_pct=0.1"
response_body = req.get(url)
if response_body.status_code == 200:
  data = response_body.json()
  print(data)
else:
  print("No json")
# Out:
# {'age': '40', 'sex': 'male', 'risk': '0.1', 'hospital': 'Southwest Hospital and Medical Center'}

# %%
def find_hospital(age, sex, risk):
  """(int, str, str)->str
  Find the appropriate hospital based on age, sex, and risk percentage.
  Example:
  >>> find_hospital(40, 'male', 0.1)
  'Southwest Hospital and Medical Center'
  >>> find_hospital(60, 'female', 0.2)
  'Select Specialty Hospital - Northeast Atlanta'
  >>> find_hospital(30, 'malesd', 0.05)
  >>> find_hospital(20, 'male', 0.2)
  'Southwest Hospital and Medical Center'
  """
  sex = sex.lower()
  if sex not in ['male', 'female']:
    return None
  else:
    #using the url replacing the ?age= with the parameter on the function.
    url = f"https://oumdj6oci2.execute-api.us-east-1.amazonaws.com/prd/?age={age}&sex={sex}&risk_pct={risk}"
    response_body = req.get(url)
    if response_body.status_code == 200:
      data = response_body.json()
      #print(data)
      return data.get('hospital')

# %%
#testing with the one above
print(find_hospital(40, 'male', 0.1))
# Out:
# Southwest Hospital and Medical Center

# %%
print(find_hospital(60, 'female', 0.2))
# Out:
# Select Specialty Hospital - Northeast Atlanta

# %%
print(find_hospital(30, 'malesd', 0.05))
# Out:
# None

# %%
print(find_hospital(20, 'male', 0.2))
# Out:
# Southwest Hospital and Medical Center

# %%
import doctest
doctest.run_docstring_examples(find_hospital, globals(),verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     find_hospital(40, 'male', 0.1)
# Expecting:
#     'Southwest Hospital and Medical Center'
# ok
# Trying:
#     find_hospital(60, 'female', 0.2)
# Expecting:
#     'Select Specialty Hospital - Northeast Atlanta'
# ok
# Trying:
#     find_hospital(30, 'malesd', 0.05)
# Expecting nothing
# ok
# Trying:
#     find_hospital(20, 'male', 0.2)
# Expecting:
#     'Southwest Hospital and Medical Center'
# ok

# %% [markdown]
# ## Part 3: Get the address for that hospital from a JSON file
#
# Great! Now we have code to tell us which hospital to send someone to... but we don't know where that hospital is. The next function we need to create is one that looks up the address of that hospital.  All of these hospitals are in Atlanta, Georgia.  We're going to use the list from this webpage to lookup the address for that hospital, based on its name.  https://www.officialusa.com/stateguides/health/hospitals/georgia.html
#
# Because we skipped the section about Beautiful Soup and working with HTML, I've converted this information into a JSON document for you.  It's available for you here.  Your code should retrieve this file using the `requests` module.
#
# `https://drive.google.com/uc?export=download&id=1fIFD-NkcdiMu941N4GjyMDWxiKsFJBw-`
#
# 1. You need to create a function called **get_address()** that takes hospital name as a parameter and searches the data from this JSON file for the hospital you want to find.
# 2. Your code will have to load the JSON and return the correct hospital based on name.
# 3. If the hospital name isn't found, the function should return None.
# 4. Be sure to use good docstring documentation and includes at least 3 test cases.

# %%
import json
#Loading to display the json file generated
url = "https://drive.google.com/uc?export=download&id=1fIFD-NkcdiMu941N4GjyMDWxiKsFJBw-"
response = req.get(url)
json_data = response.text
print(json_data)
# Out:
# {
#   "COOK MEDICAL CENTER":{
#     "City":"ADEL",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"706 NORTH PARRISH AVENUE",
#     "WEBSITE":"http:\/\/www.memorialofadel.com\/body.cfm?id=364",
#     "BEDS":60,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PHOEBE PUTNEY MEMORIAL HOSPITAL":{
#     "City":"ALBANY",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"417 THIRD AVENUE",
#     "WEBSITE":"http:\/\/phoebeputney.com\/PhoebeContentPage.aspx?nd=1523",
#     "BEDS":691,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PHOEBE PUTNEY MEMORIAL HOSPITAL - NORTH CAMPUS":{
#     "City":"ALBANY",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2000 PALMYRA ROAD",
#     "WEBSITE":"http:\/\/phoebeputney.com\/PhoebeContentPage.aspx?nd=1643",
#     "BEDS":248,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "BACON COUNTY HOSPITAL":{
#     "City":"ALMA",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"302 SOUTH WAYNE STREET",
#     "WEBSITE":"http:\/\/www.baconcountyhospital.com",
#     "BEDS":47,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PHOEBE SUMTER MEDICAL CENTER":{
#     "City":"AMERICUS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"126 HIGHWAY 280 W",
#     "WEBSITE":"http:\/\/www.phoebeputney.com\/PhoebeContentPage.aspx?nd=1479",
#     "BEDS":76,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SUMTER REGIONAL HOSPITAL":{
#     "City":"AMERICUS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"100 WHEATLEY DR",
#     "WEBSITE":"http:\/\/www.sumterregionalintranet.org\/",
#     "BEDS":143,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CALHOUN MEMORIAL HOSPITAL":{
#     "City":"ARLINGTON",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"55 R E JENNINGS AVE SE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "ATHENS REGIONAL MED CENTER":{
#     "City":"ATHENS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1199 PRINCE AVENUE",
#     "WEBSITE":"http:\/\/www.armc.org",
#     "BEDS":359,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "LANDMARK HOSPITAL OF ATHENS, LLC":{
#     "City":"ATHENS",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"775 SUNSET DRIVE",
#     "WEBSITE":"http:\/\/www.landmarkhospitals.com\/athens.aspx",
#     "BEDS":50,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "ST MARYS HEALTH CARE SYSTEM":{
#     "City":"ATHENS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1230 BAXTER STREET",
#     "WEBSITE":"https:\/\/www.stmaryshealthcaresystem.org\/",
#     "BEDS":165,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "BUCKHEAD AMBULATORY SURGICAL CENTER":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2061 PEACHTREE RD NW, UNIT 300",
#     "WEBSITE":"http:\/\/www.buckheadsurgical.com\/",
#     "BEDS":-999,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CHARTER BEHAVIORAL HEALTH SYSTEM OF ATLANTA":{
#     "City":"ATLANTA",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"811 JUNIPER STREET NE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":36,
#     "NAICS_DESC":"HOSPITALS, PSYCHIATRIC (EXCEPT CONVALESCENT)"
#   },
#   "CHILDRENS HEALTHCARE OF ATLANTA AT SCOTTISH RITE":{
#     "City":"ATLANTA",
#     "TYPE":"CHILDREN",
#     "ADDRESS":"1001 JOHNSON FERRY RD",
#     "WEBSITE":"https:\/\/www.choa.org\/",
#     "BEDS":250,
#     "NAICS_DESC":"CHILDREN'S HOSPITALS, GENERAL"
#   },
#   "EMORY DUNWOODY MEDICAL CENTER":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"4500 NORTH SHALLOWFORD ROAD",
#     "WEBSITE":"http:\/\/www.emoryhealthcare.org\/family-medicine\/index.html",
#     "BEDS":168,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "EMORY REHABILITATION HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"REHABILITATION",
#     "ADDRESS":"1441 CLIFTON ROAD",
#     "WEBSITE":"http:\/\/www.emoryhealthcare.org\/rehabilitation\/",
#     "BEDS":56,
#     "NAICS_DESC":"REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, DRUG ADDICTION)"
#   },
#   "EMORY UNIVERSITY HOSPITAL MIDTOWN":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"550 PEACHTREE ST NE",
#     "WEBSITE":"http:\/\/www.emoryhealthcare.org\/emory-university-hospital-midtown-atlanta\/",
#     "BEDS":475,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "GRADY MEMORIAL HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"80 JESSE HILL, JR DRIVE SE",
#     "WEBSITE":"https:\/\/www.gradyhealth.org\/",
#     "BEDS":953,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "HILLSIDE HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"690 COURTENAY DRIVE NE",
#     "WEBSITE":"http:\/\/www.hside.org\/",
#     "BEDS":81,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "HUGHES SPALDING CHILDRENS HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"CHILDREN",
#     "ADDRESS":"1711 TULLIE CIRCLE NE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":24,
#     "NAICS_DESC":"CHILDREN'S HOSPITALS, GENERAL"
#   },
#   "LAUREL HEIGHTS HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"934 BRIARCLIFF ROAD",
#     "WEBSITE":"http:\/\/www.laurelheightshospital.com\/index.htm",
#     "BEDS":92,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "NORTHSIDE HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1000 JOHNSON FERRY ROAD NE",
#     "WEBSITE":"https:\/\/www.northside.com\/",
#     "BEDS":571,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PIEDMONT HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1968 PEACHTREE ROAD NW",
#     "WEBSITE":"https:\/\/www.piedmont.org\/error404.aspx",
#     "BEDS":481,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PRIDE MEDICAL":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3280 HOWELL MILL ROAD NW",
#     "WEBSITE":"http:\/\/www.pridemedical.com\/",
#     "BEDS":64,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SELECT SPECIALTY HOSPITAL - ATLANTA":{
#     "City":"ATLANTA",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"550 PEACHTREE STREET, NE",
#     "WEBSITE":"http:\/\/www.selectspecialtyhospitals.com\/company\/locations\/atlanta.aspx",
#     "BEDS":30,
#     "NAICS_DESC":"EXTENDED CARE HOSPITALS (EXCEPT MENTAL, SUBSTANCE ABUSE)"
#   },
#   "SELECT SPECIALTY HOSPITAL - MIDTOWN ATLANTA":{
#     "City":"ATLANTA",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"705 JUNIPER STREET NE",
#     "WEBSITE":"http:\/\/midtownatlanta.selectspecialtyhospitals.com\/",
#     "BEDS":70,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "SELECT SPECIALTY HOSPITAL - NORTHEAST ATLANTA":{
#     "City":"ATLANTA",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"1821 CLIFTON ROAD NE",
#     "WEBSITE":"http:\/\/northeastatlanta.selectspecialtyhospitals.com\/",
#     "BEDS":18,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "SHEPHERD CENTER":{
#     "City":"ATLANTA",
#     "TYPE":"REHABILITATION",
#     "ADDRESS":"2020 PEACHTREE ROAD NW",
#     "WEBSITE":"https:\/\/www.shepherd.org\/",
#     "BEDS":100,
#     "NAICS_DESC":"REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, DRUG ADDICTION)"
#   },
#   "SOUTHWEST HOSPITAL AND MEDICAL CENTER":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"501 FAIRBURN ROAD SW",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":125,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WELLSTAR ATLANTA MEDICAL CENTER":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"303 PARKWAY DRIVE NE",
#     "WEBSITE":"https:\/\/www.wellstar.org\/locations\/pages\/wellstar-atlanta-medical-center.aspx",
#     "BEDS":762,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WESLEY WOODS GERIATRIC HOSPITAL":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1821 CLIFTON ROAD, NE",
#     "WEBSITE":"https:\/\/www.emoryhealthcare.org\/locations\/offices\/wesley-woods-geriatric-hospital.html",
#     "BEDS":82,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WEST PACES MEDICAL CENTER":{
#     "City":"ATLANTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3200 HOWELL MILL ROAD",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":294,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "AU MEDICAL CENTER":{
#     "City":"AUGUSTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1120 15TH STREET",
#     "WEBSITE":"http:\/\/www.augustahealth.org\/locations-and-maps\/medical-center",
#     "BEDS":632,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CHARLIE NORWOOD VA MEDICAL CENTER":{
#     "City":"AUGUSTA",
#     "TYPE":"MILITARY",
#     "ADDRESS":"950 15TH STREET DOWNTOWN",
#     "WEBSITE":"https:\/\/www.augusta.va.gov\/",
#     "BEDS":-999,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "DOCTORS HOSPITAL":{
#     "City":"AUGUSTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3651 WHEELER ROAD",
#     "WEBSITE":"https:\/\/doctors-hospital.net\/",
#     "BEDS":354,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "EAST CENTRAL REGIONAL HOSPITAL":{
#     "City":"AUGUSTA",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"3405 MIKE PADGETT HIGHWAY",
#     "WEBSITE":"http:\/\/www.augustareg.dhr.state.ga.us",
#     "BEDS":355,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "LIGHTHOUSE CARE CENTER OF AUGUSTA":{
#     "City":"AUGUSTA",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"3100 PERIMETER PARKWAY",
#     "WEBSITE":"http:\/\/www.lighthousecarecenters.com\/",
#     "BEDS":54,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "SELECT SPECIALTY HOSPITAL - AUGUSTA":{
#     "City":"AUGUSTA",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"1537 WALTON WAY",
#     "WEBSITE":"http:\/\/www.selectspecialtyhospitals.com\/company\/locations\/augusta.aspx",
#     "BEDS":80,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "TRINITY HOSPITAL OF AUGUSTA":{
#     "City":"AUGUSTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2260 WRIGHTSBORO ROAD",
#     "WEBSITE":"http:\/\/www.trinityofaugusta.com",
#     "BEDS":231,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "UNIVERSITY HEALTH CARE SYSTEM":{
#     "City":"AUGUSTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1350 WALTON WAY",
#     "WEBSITE":"http:\/\/www.universityhealth.org\/UniversityHospital",
#     "BEDS":581,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WALTON REHABILITATION HOSPITAL":{
#     "City":"AUGUSTA",
#     "TYPE":"REHABILITATION",
#     "ADDRESS":"1355 INDEPENDENCE DRIVE",
#     "WEBSITE":"http:\/\/www.healthsouthwalton.com\/",
#     "BEDS":58,
#     "NAICS_DESC":"REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, DRUG ADDICTION)"
#   },
#   "WELLSTAR COBB HOSPITAL":{
#     "City":"AUSTELL",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3950 AUSTELL ROAD",
#     "WEBSITE":"http:\/\/www.wellstar.org\/locations\/pages\/wellstar-cobb-hospital.aspx",
#     "BEDS":372,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "MEMORIAL HOSPITAL AND MANOR":{
#     "City":"BAINBRIDGE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1500 EAST SHOTWELL STREET",
#     "WEBSITE":"http:\/\/www.mh-m.org",
#     "BEDS":80,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "APPLING HEALTHCARE SYSTEM":{
#     "City":"BAXLEY",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"163 EAST TOLLISON STREET",
#     "WEBSITE":"http:\/\/www.appling-hospital.org",
#     "BEDS":49,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "UNION GENERAL HOSPITAL":{
#     "City":"BLAIRSVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"35 HOSPITAL CIRCLE",
#     "WEBSITE":"http:\/\/www.uniongeneralhospital.com",
#     "BEDS":45,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PIONEER COMMUNITY HOSPITAL OF EARLY":{
#     "City":"BLAKELY",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"11740 COLUMBIA STREET",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "FANNIN REGIONAL HOSPITAL":{
#     "City":"BLUE RIDGE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2855 OLD HIGHWAY 5",
#     "WEBSITE":"http:\/\/www.fanninregionalhospital.com",
#     "BEDS":50,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "BOWDON AREA HOSPITAL AND REHAB CENTER":{
#     "City":"BOWDON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"501 MITCHELL AVENUE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":41,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "HIGGINS GENERAL HOSPITAL":{
#     "City":"BREMEN",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"200 ALLEN MEMORIAL DRIVE",
#     "WEBSITE":"http:\/\/www.tanner.org\/Main\/HigginsGeneralHospitalBremen.aspx",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SOUTHEAST GEORGIA HEALTH SYSTEM- BRUNSWICK CAMPUS":{
#     "City":"BRUNSWICK",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2415 PARKWOOD DRIVE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":300,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "MEDICAL CENTER OF PEACH COUNTY, THE":{
#     "City":"BYRON",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"1960 HIGHWAY 247 CONNECTOR",
#     "WEBSITE":"https:\/\/www.navicenthealth.org\/service-center\/page\/the-medical-center-of-peach-county",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "GRADY GENERAL HOSPITAL":{
#     "City":"CAIRO",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1155 FIFTH STREET SE",
#     "WEBSITE":"https:\/\/archbold.org\/",
#     "BEDS":60,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "GORDON HOSPITAL":{
#     "City":"CALHOUN",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1035 RED BUD ROAD",
#     "WEBSITE":"http:\/\/www.gordonhospital.com",
#     "BEDS":80,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "MITCHELL COUNTY HOSPITAL":{
#     "City":"CAMILLA",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"90 STEPHENS STREET",
#     "WEBSITE":"http:\/\/archbold.org\/",
#     "BEDS":23,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "NORTHSIDE HOSPITAL - CHEROKEE":{
#     "City":"CANTON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"201 HOSPITAL ROAD",
#     "WEBSITE":"https:\/\/www.northside.com\/",
#     "BEDS":79,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "TANNER MEDICAL CENTER - CARROLLTON":{
#     "City":"CARROLLTON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"705 DIXIE STREET",
#     "WEBSITE":"http:\/\/www.tanner.org\/hospitals-and-facilities\/hospitals\/tanner-medical-center-carrollton",
#     "BEDS":181,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CARTERSVILLE MEDICAL CENTER":{
#     "City":"CARTERSVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"960 JOE FRANK HARRIS PARKWAY",
#     "WEBSITE":"https:\/\/www.piedmont.org\/locations\/piedmont-cartersville\/about",
#     "BEDS":80,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "POLK MEDICAL CENTER":{
#     "City":"CEDARTOWN",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"424 NORTH MAIN STREET",
#     "WEBSITE":"http:\/\/www.polkhospital.org\/",
#     "BEDS":18,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "MURRAY MEDICAL CENTER":{
#     "City":"CHATSWORTH",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"707 OLD DALTON ELLIJAY ROAD, PO BOX 1406",
#     "WEBSITE":"http:\/\/www.murraymedical.org\/",
#     "BEDS":42,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "EVANS MEMORIAL HOSPITAL":{
#     "City":"CLAXTON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"200 NORTH RIVER STREET",
#     "WEBSITE":"http:\/\/www.evansmemorialhospital.org",
#     "BEDS":49,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "MOUNTAIN LAKES MEDICAL CENTER":{
#     "City":"CLAYTON",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"196 RIDGECREST CIRCLE",
#     "WEBSITE":"http:\/\/mountainlakesmedicalcenter.com\/main.html",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "BLECKLEY MEMORIAL HOSPITAL":{
#     "City":"COCHRAN",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"145 EAST PEACOCK STREET",
#     "WEBSITE":"http:\/\/bleckleymemorial.com\/",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SO CRESCENT BEH HLTH SYS - ANCHOR HOSPITAL CAMPUS":{
#     "City":"COLLEGE PARK",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"5454 YORKTOWNE DRIVE",
#     "WEBSITE":"http:\/\/anchorhospital.com\/",
#     "BEDS":122,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "MILLER COUNTY HOSPITAL":{
#     "City":"COLQUITT",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"209 NORTH CUTHBERT STREET",
#     "WEBSITE":"http:\/\/www.millercountyhospital.com",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "BRADLEY CENTER OF SAINT FRANCIS":{
#     "City":"COLUMBUS",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"2000 SIXTEENTH AVENUE",
#     "WEBSITE":"http:\/\/www.wecareforlife.com\/",
#     "BEDS":-999,
#     "NAICS_DESC":"HOSPITALS, PSYCHIATRIC (EXCEPT CONVALESCENT)"
#   },
#   "DOCTORS SPECIALTY HOSPITAL":{
#     "City":"COLUMBUS",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"616 19TH STREET",
#     "WEBSITE":"http:\/\/www.columbusspecialtyhospital.net\/",
#     "BEDS":169,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "MIDTOWN MEDICAL CENTER":{
#     "City":"COLUMBUS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"710 CENTER ST, BOX 951",
#     "WEBSITE":"http:\/\/columbusregional.com\/locations\/midtown-medical-center\/",
#     "BEDS":413,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "MIDTOWN MEDICAL CENTER WEST":{
#     "City":"COLUMBUS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"616 19TH STREET",
#     "WEBSITE":"https:\/\/columbusregional.com\/",
#     "BEDS":171,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "NORTHSIDE MEDICAL CENTER":{
#     "City":"COLUMBUS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"100 FRIST COURT",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":100,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "ST FRANCIS HOSPITAL":{
#     "City":"COLUMBUS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2122 MANCHESTER EXPRESSWAY",
#     "WEBSITE":"http:\/\/www.sfhga.com",
#     "BEDS":376,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WEST CENTRAL GEORGIA REGIONAL HOSPITAL":{
#     "City":"COLUMBUS",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"3000 SCHATULGA ROAD",
#     "WEBSITE":"https:\/\/bestswisscbd.com\/EN-002.php?wp=https:\/\/wcgrh.org",
#     "BEDS":145,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "NORTHRIDGE MEDICAL CENTER":{
#     "City":"COMMERCE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"70 MEDICAL CENTER DRIVE",
#     "WEBSITE":"http:\/\/www.northridgemc.com\/",
#     "BEDS":257,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "ROCKDALE HOSPITAL AND HEALTH SYSTEM":{
#     "City":"CONYERS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1412 MILSTEAD AVENUE NE",
#     "WEBSITE":"http:\/\/www.rockdalemedicalcenter.org",
#     "BEDS":146,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CRISP REGIONAL HOSPITAL":{
#     "City":"CORDELE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"902 7TH STREET NORTH",
#     "WEBSITE":"http:\/\/www.crispregional.org",
#     "BEDS":73,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PIEDMONT NEWTON HOSPITAL":{
#     "City":"COVINGTON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"5126 HOSPITAL DRIVE",
#     "WEBSITE":"http:\/\/www.piedmont.org\/locations\/piedmont-newton\/newton-home",
#     "BEDS":97,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "NORTHSIDE HOSPITAL FORSYTH":{
#     "City":"CUMMING",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1200 NORTHSIDE FORSYTH DR",
#     "WEBSITE":"http:\/\/www.northside.com\/forsyth",
#     "BEDS":187,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SOUTHWEST GEORGIA REGIONAL MEDICAL CENTER":{
#     "City":"CUTHBERT",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"361 RANDOLPH STREET",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CHESTATEE REGIONAL HOSPITAL":{
#     "City":"DAHLONEGA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"227 MOUNTAIN DR",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":49,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WELLSTAR PAULDING HOSPITAL":{
#     "City":"DALLAS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"600 WEST MEMORIAL DRIVE",
#     "WEBSITE":"https:\/\/www.wellstar.org\/",
#     "BEDS":216,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "HAMILTON MEDICAL CENTER":{
#     "City":"DALTON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1200 MEMORIAL DRIVE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":282,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "ATLANTA VA HEALTH MEDICAL CENTER":{
#     "City":"DECATUR",
#     "TYPE":"MILITARY",
#     "ADDRESS":"1670 CLAIRMONT ROAD",
#     "WEBSITE":"https:\/\/www.atlanta.va.gov\/",
#     "BEDS":-999,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "DEKALB MEDICAL AT DECATUR":{
#     "City":"DECATUR",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"450 NORTH CANDLER STREET",
#     "WEBSITE":"http:\/\/www.dekalbmedical.org\/locations\/locations-module\/dekalb-medical-downtown-decatur\/",
#     "BEDS":76,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "DEKALB MEDICAL CENTER AT NORTH DECATUR":{
#     "City":"DECATUR",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2701 N DECATUR ROAD",
#     "WEBSITE":"http:\/\/www.dekalbmedical.org\/",
#     "BEDS":451,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "GEORGIA REGIONAL HOSPITAL AT ATLANTA":{
#     "City":"DECATUR",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"3073 PANTHERSVILLE ROAD",
#     "WEBSITE":"http:\/\/www.atlantareg.dhr.state.ga.us",
#     "BEDS":334,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "HABERSHAM COUNTY MEDICAL CTR":{
#     "City":"DEMOREST",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"541 HISTORIC HIGHWAY 441-NORTH",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":53,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "DONALSONVILLE HOSPITAL":{
#     "City":"DONALSONVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"102 HOSPITAL CIRCLE",
#     "WEBSITE":"http:\/\/donalsonvillehospital.org\/",
#     "BEDS":65,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "COFFEE REGIONAL MEDICAL CENTER":{
#     "City":"DOUGLAS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1101 OCILLA ROAD",
#     "WEBSITE":"http:\/\/www.coffeeregional.org",
#     "BEDS":88,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WELLSTAR DOUGLAS HOSPITAL":{
#     "City":"DOUGLASVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"8954 HOSPITAL DRIVE",
#     "WEBSITE":"https:\/\/www.wellstar.org\/",
#     "BEDS":102,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "YOUTH VILLAGES - INNER HARBOUR CAMPUS":{
#     "City":"DOUGLASVILLE",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"4685 DORSETT SHOALS ROAD",
#     "WEBSITE":"http:\/\/www.youthvillages.org\/what-we-do\/residential-programs\/inner-harbour-campus.aspx",
#     "BEDS":90,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "CHILDRENS HEALTHCARE OF ATLANTA - EGLESTON":{
#     "City":"DRUID HILLS",
#     "TYPE":"CHILDREN",
#     "ADDRESS":"1405 CLIFTON ROAD NE",
#     "WEBSITE":"http:\/\/www.choa.org\/egleston",
#     "BEDS":258,
#     "NAICS_DESC":"CHILDREN'S HOSPITALS, GENERAL"
#   },
#   "EMORY UNIVERSITY HOSPITAL":{
#     "City":"DRUID HILLS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1364 CLIFTON ROAD NE",
#     "WEBSITE":"http:\/\/www.emoryhealthcare.org\/emory-university-hospital-atlanta\/index.html",
#     "BEDS":579,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CARL VINSON VA MEDICAL CENTER":{
#     "City":"DUBLIN",
#     "TYPE":"MILITARY",
#     "ADDRESS":"1826 VETERANS BLVD",
#     "WEBSITE":"http:\/\/www.dublin.va.gov\/",
#     "BEDS":178,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "FAIRVIEW PARK HOSPITAL":{
#     "City":"DUBLIN",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"200 INDUSTRIAL BOULEVARD",
#     "WEBSITE":"http:\/\/www.fairviewparkhospital.com",
#     "BEDS":190,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "GWINNETT MEDICAL CENTER - DULUTH":{
#     "City":"DULUTH",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3620 HOWELL FERRY ROAD",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":111,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   
",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1514 VERNON ROAD",
#     "WEBSITE":"https:\/\/www.wellstar.org\/locations\/pages\/wellstar-west-georgia-medical-center.aspx",
#     "BEDS":276,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "LOUIS SMITH MEMORIAL HOSPITAL":{
#     "City":"LAKELAND",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"116 WEST THIGPEN AVENUE",
#     "WEBSITE":"https:\/\/www.sgmc.org\/locations\/sgmc_lanier_campus.aspx",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "TY COBB REGIONAL MEDICAL CENTER, LLC":{
#     "City":"LAVONIA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"367 CLEAR CREEK PARKWAY",
#     "WEBSITE":"http:\/\/www.stmaryssacredheart.org\/",
#     "BEDS":56,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "GWINNETT HOSPITAL SYSTEM":{
#     "City":"LAWRENCEVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1000 MEDICAL CENTER BOULEVARD",
#     "WEBSITE":"http:\/\/www.gwinnettmedicalcenter.org",
#     "BEDS":353,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SUMMITRIDGE CENTER- PSYCHIATRY & ADDICTIVE MED":{
#     "City":"LAWRENCEVILLE",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"250 SCENIC HIGHWAY",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":76,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "DEKALB MEDICAL CENTER AT HILLANDALE":{
#     "City":"LITHONIA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2801 DEKALB MEDICAL PARKWAY",
#     "WEBSITE":"http:\/\/www.dekalbmedical.org",
#     "BEDS":100,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "JEFFERSON HOSPITAL":{
#     "City":"LOUISVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1067 PEACHTREE STREET",
#     "WEBSITE":"http:\/\/www.jeffersonhosp.com",
#     "BEDS":37,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CHILDRENS HOSPITAL NAVICENT HEALTH":{
#     "City":"MACON",
#     "TYPE":"CHILDREN",
#     "ADDRESS":"888 PINE STREET",
#     "WEBSITE":"http:\/\/www.childrenshospitalmacon.org\/",
#     "BEDS":112,
#     "NAICS_DESC":"CHILDREN'S HOSPITALS, GENERAL"
#   },
#   "COLISEUM MEDICAL CENTERS":{
#     "City":"MACON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"350 HOSPITAL DRIVE",
#     "WEBSITE":"https:\/\/www.piedmont.org\/locations\/piedmont-macon-medical\/about",
#     "BEDS":250,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "COLISEUM NORTHSIDE HOSPITAL":{
#     "City":"MACON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"400 CHARTER BOULEVARD",
#     "WEBSITE":"https:\/\/www.piedmont.org\/locations\/piedmont-macon-medical\/about",
#     "BEDS":103,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "COLISEUM PSYCHIATRIC HOSPITAL":{
#     "City":"MACON",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"340 HOSPITAL DRIVE, BOX 9366",
#     "WEBSITE":"https:\/\/www.piedmont.org\/locations\/piedmont-macon-medical\/about",
#     "BEDS":60,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "LAKE BRIDGE BEHAVIORAL HEALTH SYSTEM":{
#     "City":"MACON",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"3500 RIVERSIDE DRIVE",
#     "WEBSITE":"http:\/\/lakebridgebhs.com\/",
#     "BEDS":40,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "MEDICAL CENTER OF CENTRAL GEORGIA":{
#     "City":"MACON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"777 HEMLOCK STREET",
#     "WEBSITE":"https:\/\/www.navicenthealth.org\/",
#     "BEDS":637,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "REGENCY HOSPITAL COMPANY OF MACON, LLC":{
#     "City":"MACON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"535 COLISEUM DRIVE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":34,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "REHABILITATION HOSPITAL NAVICENT HEALTH":{
#     "City":"MACON",
#     "TYPE":"REHABILITATION",
#     "ADDRESS":"3351 NORTHSIDE DRIVE",
#     "WEBSITE":"https:\/\/www.navicenthealth.org\/service-center\/rehabilitation-hospital-navicent-health",
#     "BEDS":58,
#     "NAICS_DESC":"REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, DRUG ADDICTION)"
#   },
#   "MORGAN MEMORIAL HOSPITAL":{
#     "City":"MADISON",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"1077 SOUTH MAIN STREET",
#     "WEBSITE":"http:\/\/www.mmh.org",
#     "BEDS":41,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WELLSTAR KENNESTONE HOSPITAL":{
#     "City":"MARIETTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"677 CHURCH STREET",
#     "WEBSITE":"http:\/\/www.wellstar.org\/locations\/pages\/wellstar-kennestone-hospital.aspx",
#     "BEDS":580,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WELLSTAR WINDY HILL HOSPITAL":{
#     "City":"MARIETTA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2540 WINDY HILL ROAD",
#     "WEBSITE":"http:\/\/www.wellstar.org\/locations\/pages\/wellstar-windy-hill-hospital.aspx",
#     "BEDS":55,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CANDLER COUNTY HOSPITAL":{
#     "City":"METTER",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"400 CEDAR ROAD",
#     "WEBSITE":"http:\/\/www.candlercountyhospital.com",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CENTRAL STATE HOSPITAL PSYCHIATRIC":{
#     "City":"MILLEDGEVILLE",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"620 BROAD STREET",
#     "WEBSITE":"http:\/\/dbhdd.georgia.gov\/central-state-hospital-milledgeville",
#     "BEDS":200,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "OCONEE REGIONAL MEDICAL CENTER":{
#     "City":"MILLEDGEVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"821 N COBB STREET, POST OFFICE BOX 690",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":140,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "OPTIM MEDICAL CENTER JENKINS":{
#     "City":"MILLEN",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"931 EAST WINTHROPE AVENUE",
#     "WEBSITE":"http:\/\/jenkins.optimhealth.com\/",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CLEARVIEW  REGIONAL MEDICAL CENTER":{
#     "City":"MONROE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2151 WEST SPRING STREET",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":77,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CLEARVIEW REGIONAL MEDICAL CENTER":{
#     "City":"MONROE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"330 ALCOVY STREET",
#     "WEBSITE":"http:\/\/www.clearviewregionalmedicalcenter.com\/locations\/clearview-regional-medical-center",
#     "BEDS":115,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "FLINT RIVER COMMUNITY HOSPITAL":{
#     "City":"MONTEZUMA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"509 SUMTER STREET",
#     "WEBSITE":"http:\/\/www.flintriverhospital.com\/",
#     "BEDS":49,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "JASPER MEMORIAL HOSPITAL":{
#     "City":"MONTICELLO",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"898 COLLEGE STREET",
#     "WEBSITE":"http:\/\/www.jaspermemorialhospital.org",
#     "BEDS":17,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "COLQUITT REGIONAL MEDICAL CENTER":{
#     "City":"MOULTRIE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3131 THOMASVILLE HWY, BOX 40",
#     "WEBSITE":"http:\/\/www.colquittregional.com",
#     "BEDS":99,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "TURNING POINT HOSPITAL":{
#     "City":"MOULTRIE",
#     "TYPE":"SPECIAL",
#     "ADDRESS":"3015 VETERANS PKWY SOUTH",
#     "WEBSITE":"http:\/\/www.turningpointcare.com",
#     "BEDS":59,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "SGMC BERRIEN CAMPUS":{
#     "City":"NASHVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1221 E MCPHERSON AVENUE",
#     "WEBSITE":"http:\/\/www.berrienhospital.com\/",
#     "BEDS":63,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "HEALTHSOUTH REHABILITATION HOSPITAL OF NEWNAN":{
#     "City":"NEWNAN",
#     "TYPE":"REHABILITATION",
#     "ADDRESS":"2101 EAST NEWNAN CROSSING BLVD",
#     "WEBSITE":"http:\/\/www.healthsouthnewnan.com\/",
#     "BEDS":50,
#     "NAICS_DESC":"REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM
",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"11 UPPER RIVERDALE ROAD SW",
#     "WEBSITE":"http:\/\/www.southernregional.org",
#     "BEDS":331,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "FLOYD MEDICAL CENTER":{
#     "City":"ROME",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"304 TURNER MCCALL BOULEVARD",
#     "WEBSITE":"http:\/\/www.floyd.org",
#     "BEDS":284,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "KINDRED HOSPITAL ROME":{
#     "City":"ROME",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"320 TURNER MCCALL BOULEVARD",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":45,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "NORTHWEST GEORGIA REGIONAL HOSPITAL":{
#     "City":"ROME",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"1305 REDMOND CIRCLE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":297,
#     "NAICS_DESC":"HOSPITALS, PSYCHIATRIC (EXCEPT CONVALESCENT)"
#   },
#   "REDMOND REGIONAL MEDICAL CENTER":{
#     "City":"ROME",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"501 REDMOND ROAD",
#     "WEBSITE":"http:\/\/www.redmondregional.com",
#     "BEDS":230,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WELLSTAR NORTH FULTON HOSPITAL":{
#     "City":"ROSWELL",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3000 HOSPITAL BOULEVARD",
#     "WEBSITE":"https:\/\/www.wellstar.org\/locations\/pages\/wellstar-north-fulton-hospital.aspx",
#     "BEDS":202,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "BROWN MEMORIAL CONVALESCENT CENTER":{
#     "City":"ROYSTON",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"545 COOK STREET",
#     "WEBSITE":"http:\/\/tycobbhealthcare.com\/ProgramsServices\/LongTermCare\/BrownMemorialConvalescentCenter.aspx",
#     "BEDS":144,
#     "NAICS_DESC":"EXTENDED CARE HOSPITALS (EXCEPT MENTAL, SUBSTANCE ABUSE)"
#   },
#   "TY COBB HEALTHCARE SYSTEM - COBB MEMORIAL HOSPITAL":{
#     "City":"ROYSTON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"577 FRANKLIN SPRINGS STREET",
#     "WEBSITE":"http:\/\/tycobbhealthcare.com\/Home.aspx",
#     "BEDS":71,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WASHINGTON COUNTY REGIONAL MEDICAL CENTER":{
#     "City":"SANDERSVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"610 SPARTA HIGHWAY",
#     "WEBSITE":"http:\/\/www.wcrmc.com",
#     "BEDS":116,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SAINT JOSEPHS HOSPITAL OF ATLANTA":{
#     "City":"SANDY SPRINGS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"5665 PEACHTREE DUNWOODY RD NE",
#     "WEBSITE":"http:\/\/www.stjosephsatlanta.org",
#     "BEDS":258,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "CANDLER HOSPITAL":{
#     "City":"SAVANNAH",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"5353 REYNOLDS STREET",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":320,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "COASTAL BEHAVIORAL HEALTH":{
#     "City":"SAVANNAH",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"633 STEPHENSON AVENUE",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":50,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "COASTAL HARBOR TREATMENT CENTER":{
#     "City":"SAVANNAH",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"1150 CORNELL AVENUE",
#     "WEBSITE":"http:\/\/www.coastalharbor.com",
#     "BEDS":121,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "GEORGIA REGIONAL HOSPITAL":{
#     "City":"SAVANNAH",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"1915 EISENHOWER DRIVE",
#     "WEBSITE":"http:\/\/www.garegionalsavannah.com",
#     "BEDS":262,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "LANDMARK HOSPITAL OF SAVANNAH":{
#     "City":"SAVANNAH",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"800 E 68TH STREET",
#     "WEBSITE":"http:\/\/www.landmarkhospitals.com\/savannah.aspx",
#     "BEDS":50,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "MEMORIAL HEALTH UNIV MED CEN, INC":{
#     "City":"SAVANNAH",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"4700 WATERS AVENUE",
#     "WEBSITE":"https:\/\/memorialhealth.com\/",
#     "BEDS":530,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "REHABILITATION HOSPITAL OF SAVANNAH":{
#     "City":"SAVANNAH",
#     "TYPE":"REHABILITATION",
#     "ADDRESS":"6510 SEAWRIGHT DRIVE",
#     "WEBSITE":"http:\/\/savannahrehabilitationhospital.com\/",
#     "BEDS":50,
#     "NAICS_DESC":"REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, DRUG ADDICTION)"
#   },
#   "SELECT SPECIALTY HOSPITAL - SAVANNAH":{
#     "City":"SAVANNAH",
#     "TYPE":"LONG TERM CARE",
#     "ADDRESS":"5353 REYNOLDS STREET",
#     "WEBSITE":"http:\/\/savannah.selectspecialtyhospitals.com\/",
#     "BEDS":40,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "ST JOSEPHS HOSPITAL - SAVANNAH":{
#     "City":"SAVANNAH",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"11705 MERCY BOULEVARD",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":294,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "EMORY-ADVENTIST HOSPITAL":{
#     "City":"SMYRNA",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"3949 SOUTH COBB DRIVE",
#     "WEBSITE":"http:\/\/www.emoryadventist.org",
#     "BEDS":75,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "RIDGEVIEW INSTITUTE":{
#     "City":"SMYRNA",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"3995 SOUTH COBB DRIVE SE",
#     "WEBSITE":"http:\/\/www.ridgeviewinstitute.com",
#     "BEDS":92,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "EASTSIDE MEDICAL CENTER":{
#     "City":"SNELLVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1700 MEDICAL WAY",
#     "WEBSITE":"http:\/\/eastsidemedical.com",
#     "BEDS":247,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "EFFINGHAM HOSPITAL":{
#     "City":"SPRINGFIELD",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"459 HIGHWAY 119 SOUTH",
#     "WEBSITE":"http:\/\/www.effinghamhospital.com",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SOUTHEAST GEORGIA HEALTH SYSTEM - CAMDEN CAMPUS":{
#     "City":"ST. MARYS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"2000 DAN PROCTOR DRIVE",
#     "WEBSITE":"http:\/\/www.sghs.org\/locations\/hospital-campuses\/camden\/",
#     "BEDS":40,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "ST SIMONS BY-THE-SEA HOSPITAL":{
#     "City":"ST. SIMONS",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"2927 DEMERE ROAD",
#     "WEBSITE":"http:\/\/www.ssbythesea.com",
#     "BEDS":101,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "EAST GEORGIA REGIONAL MEDICAL CENTER":{
#     "City":"STATESBORO",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1499 FAIR ROAD",
#     "WEBSITE":"http:\/\/www.eastgeorgiaregional.com",
#     "BEDS":150,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WILLINGWAY HOSPITAL":{
#     "City":"STATESBORO",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"311 JONES MILL ROAD",
#     "WEBSITE":"http:\/\/www.willingway.com",
#     "BEDS":40,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "PIEDMONT HENRY HOSPITAL":{
#     "City":"STOCKBRIDGE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1133 EAGLE'S LANDING PARKWAY",
#     "WEBSITE":null,
#     "BEDS":215,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SO CRESCENT BEH HLTH SYS - CRESCENT PINES CAMPUS":{
#     "City":"STOCKBRIDGE",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"1000 EAGLES LANDING PARKWAY",
#     "WEBSITE":"http:\/\/www.crescentpineshospital.com\/",
#     "BEDS":50,
#     "NAICS_DESC":"PSYCHIATRIC AND SUBSTANCE ABUSE HOSPITALS"
#   },
#   "CHATTOOGA MEDICAL CENTER":{
#     "City":"SUMMERVILLE",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"11766 US 27",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":31,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "EMANUEL MEDICAL CENTER":{
#     "City":"SWAINSBORO",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"117 KITE ROAD",
#     "WEBSITE":"http:\/\/www.emanuelmedical.org",
#     "BEDS":72,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "OPTIM MEDICAL CENTER SCREVEN":{
#     "City":"SYLVANIA",
#     "TYPE":"CRITICAL ACCESS",
#     "ADDRESS":"215 MIMS ROAD",
#     "WEBSITE":"http:\/\/screven.optimhealth.com\/",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   
",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":32,
#     "NAICS_DESC":"SPECIALTY (EXCEPT PSYCHIATRIC AND SUBSTANCE ABUSE) HOSPITALS"
#   },
#   "ROOSEVELT WARM SPRINGS REHABILITATION HOSPITAL":{
#     "City":"WARM SPRINGS",
#     "TYPE":"REHABILITATION",
#     "ADDRESS":"6135 ROOSEVELT HIGHWAY",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":52,
#     "NAICS_DESC":"REHABILITATION HOSPITALS (EXCEPT ALCOHOLISM, DRUG ADDICTION)"
#   },
#   "WARM SPRINGS MEDICAL CENTER":{
#     "City":"WARM SPRINGS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"5995 SPRING STREET",
#     "WEBSITE":"http:\/\/www.warmspringsmc.org",
#     "BEDS":104,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "HOUSTON MEDICAL CENTER":{
#     "City":"WARNER ROBINS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1601 WATSON BOULEVARD",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":237,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WILLS MEMORIAL HOSPITAL":{
#     "City":"WASHINGTON",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"120 GORDON STREET",
#     "WEBSITE":"https:\/\/www.willsmemorialhospital.com\/",
#     "BEDS":25,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "MAYO CLINIC HEALTH SYSTEM IN WAYCROSS, INC":{
#     "City":"WAYCROSS",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"1900 TEBEAU STREET",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":231,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "SATILLA PARK HOSPITAL":{
#     "City":"WAYCROSS",
#     "TYPE":"PSYCHIATRIC",
#     "ADDRESS":"2500 SATILLA PARKWAY",
#     "WEBSITE":"NOT AVAILABLE",
#     "BEDS":53,
#     "NAICS_DESC":"HOSPITALS, PSYCHIATRIC (EXCEPT CONVALESCENT)"
#   },
#   "BURKE MEDICAL CENTER":{
#     "City":"WAYNESBORO",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"351 S LIBERTY STREET",
#     "WEBSITE":"http:\/\/burkemedical.net\/",
#     "BEDS":40,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "WILDWOOD LIFESTYLE CENTER AND HOSPITAL":{
#     "City":"WILDWOOD",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"435 LIFESTYLE LANE",
#     "WEBSITE":"http:\/\/www.wildwoodhealth.org\/",
#     "BEDS":13,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   },
#   "BARROW MEDICAL CENTER":{
#     "City":"WINDER",
#     "TYPE":"GENERAL ACUTE CARE",
#     "ADDRESS":"316 NORTH BROAD STREET",
#     "WEBSITE":"http:\/\/www.barrowregional.com",
#     "BEDS":56,
#     "NAICS_DESC":"GENERAL MEDICAL AND SURGICAL HOSPITALS"
#   }
# }

# %%
def get_address(hospital_name):
  """(str)->str
  Get the address of a hospital based on its name.
  example:
  >>> get_address('COOK MEDICAL CENTER')
  '706 NORTH PARRISH AVENUE'
  >>> get_address('DOOLY MEDICAL CENTER')
  '1300 UNION STREET'
  >>> get_address('Southwest Hospital and Medical Center')
  '501 FAIRBURN ROAD SW'
  >>> get_address('Southwest Hospital and Medical Centerss')
  >>> get_address('HIGGINS GENERAL HOSPITAL')
  '200 ALLEN MEMORIAL DRIVE'
  """
  hospital_name = hospital_name.lower()
  hospitals = json.loads(json_data)
  for hospital in hospitals.items():
    if hospital[0].lower() == hospital_name:
      return hospital[1].get('ADDRESS')

# %%
print(get_address('Southwest Hospital and Medical Center'))
print(get_address('COOK MEDICAL CENTER'))
print(get_address('DOOLY MEDICAL CENTER'))
print(get_address('HIGGINS GENERAL HOSPITAL'))
print(get_address('HIGGINS GENERAL HOSPITALgftr'))
# Out:
# 501 FAIRBURN ROAD SW
# 706 NORTH PARRISH AVENUE
# 1300 UNION STREET
# 200 ALLEN MEMORIAL DRIVE
# None

# %%
import doctest
doctest.run_docstring_examples(get_address, globals(),verbose=True)
# Out:
# Finding tests in NoName
# Trying:
#     get_address('COOK MEDICAL CENTER')
# Expecting:
#     '706 NORTH PARRISH AVENUE'
# ok
# Trying:
#     get_address('DOOLY MEDICAL CENTER')
# Expecting:
#     '1300 UNION STREET'
# ok
# Trying:
#     get_address('Southwest Hospital and Medical Center')
# Expecting:
#     '501 FAIRBURN ROAD SW'
# ok
# Trying:
#     get_address('Southwest Hospital and Medical Centerss')
# Expecting nothing
# ok
# Trying:
#     get_address('HIGGINS GENERAL HOSPITAL')
# Expecting:
#     '200 ALLEN MEMORIAL DRIVE'
# ok

# %% [markdown]
# ## Part 4: Run the risk calculator on a population
#
# At the link below, there is a file called `people.psv`.  It is a pipe-delimited (`|`) file with columns that match the inputs for the PRIEST calculation above.  Your code should use the `requests` module to retrieve the file from this URL.
#
# `https://drive.google.com/uc?export=download&id=1fLxJN9YGUqmqExrilxSS8furwUER5HHh`
#
#
# In addition, the file has a patient identifier in the first column.
#
# 1. Write a function called **process_people()** that takes the file location above as its only parameter. Your Python program should use your code above to process all of these rows, determine the hospital and address, and return a list whose items are a dictionary like this: `{ patient_number: [sex, age, breath, o2sat, heart, systolic, temp, alertness, inspired, status, hospital, address]}`.  Look at the file in Part 5 for what the output looks like.
# 2. Be sure to use good docstrings, but you don't need any tests in your doc strings.  I've provided those for you withe file in Part 5.
#
#
# **NOTE** that when running your code for all the 100 records in the `people.psv` file, it may take a few minutes to complete.  You're making multiple calls to the internet for each record, so that can take a little while.

# %%
def process_people(file_location):
  """(file)->dict
  Process the data from the file and determine hospital and address
 """
  response = req.get(file_location)
  data = response.text
  rows = data.strip().split('\n')
  #used to understand the structure of the file.
  #print(rows)
  header_skipped = False
  processed_data = {}
  for row in rows:
    #skipping the headers
    if not header_skipped:
      header_skipped = True
      continue
    patient, sex, age, breath, o2sat, heart, systolicbp, temp, alertness, inspired, status = row.split('|')
    # print(patient, sex, age, breath, o2sat, heart, systolicbp, temp, alertness, inspired, status)
    #converting the columns to correct data types
    sex = sex.lower()
    alertness = alertness.lower()
    inspired= inspired.lower()
    status = status.lower()
    age = int(age)
    breath = float(breath)
    o2sat = float(o2sat)
    heart = int(heart)
    systolicbp = float(systolicbp)
    temp = float(temp)

    risk = priest(sex, age, breath, o2sat, heart, systolicbp, temp, alertness, inspired, status)
    #print(f"Patient: {patient}, Risk: {risk}")
    if risk is not None:
      hospital = find_hospital(age, sex, risk)
      address = get_address(hospital)
      if hospital is not None:
        processed_data[patient] = [
            sex,
            age,
            breath,
            o2sat,
            heart,
            systolicbp,
            temp,
            alertness,
            inspired,
            status,
            risk,
            hospital,
            address]
  json_data = json.dumps(processed_data)
  return json_data

# %%
file_location = "https://drive.google.com/uc?export=download&id=1fLxJN9YGUqmqExrilxSS8furwUER5HHh"
result = process_people(file_location)
print(result)
# Out:
# {"E9559": ["female", 40, 24.0, 0.96, 105, 115.0, 34.9, "alert", "air", "unrestricted normal activity", 0.15, "Select Specialty Hospital - Northeast Atlanta", "1821 CLIFTON ROAD NE"], "
"Select Specialty Hospital - Northeast Atlanta", "1821 CLIFTON ROAD NE"], "E2360": ["male", 40, 20.0, 0.96, 51, 95.0, 34.9, "alert", "supplemental oxygen", "unrestricted normal activity", 0.22, "Southwest Hospital and Medical Center", "501 FAIRBURN ROAD SW"], "E3447": ["male", 80, 22.0, 0.96, 41, 115.0, 38.1, "alert", "air", "limited activity, can self-care", 0.29, "Wesley Woods Geriatric Hospital", "1821 CLIFTON ROAD, NE"], "E8208": ["female", 18, 23.0, 0.96, 135, 115.0, 38.1, "alert", "air", "unrestricted normal activity", 0.15, "Select Specialty Hospital - Northeast Atlanta", "1821 CLIFTON ROAD NE"], "E4428": ["female", 40, 23.0, 0.96, 38, 115.0, 36.3, "alert", "air", "unrestricted normal activity", 0.09, "Select Specialty Hospital - Northeast Atlanta", "1821 CLIFTO ...

# %%
import doctest
doctest.run_docstring_examples(process_people, globals(),verbose=True)
# Out:
# Finding tests in NoName

# %% [markdown]
# ## Part 5: Checking your final results
#
# The final step is to check your results.  You should be able to compare your results to the output in `people_results.json` at the link below.  Write some code to check your results.  This does not need to be a function.
#
# `https://drive.google.com/uc?export=download&id=1gx1SSC20mO5XL6uYD0mdcM_cL91fcIW5`

# %%
url = "https://drive.google.com/uc?export=download&id=1gx1SSC20mO5XL6uYD0mdcM_cL91fcIW5"
file_locations = "https://drive.google.com/uc?export=download&id=1fLxJN9YGUqmqExrilxSS8furwUER5HHh"
response = req.get(url)
data = response.text
data_json = json.loads(data)
result = process_people(file_locations)
info = json.loads(result)

print(info)
print(data_json)

print('\n')

print(f"Keys in 'info': {list(info.keys())}")
print(f"Keys in 'data_json': {list(data_json.keys())}")
similar_keys = set(info.keys()) & set(data_json.keys())
print(f"Number of similar keys: {len(similar_keys)}")
print(f"Similar keys: {list(similar_keys)}")
not_similar_keys = set(info.keys()) ^ set(data_json.keys())
print(f"Number of not similar keys: {len(not_similar_keys)}")
print(f"Keys that are not similar: {list(not_similar_keys)}")

if info.keys() == data_json.keys():
  print("OK")
else:
  print("There is an error")

print('\n')

#modified the strings to lower cases
for key, value in data_json.items():
    value[0] = value[0].lower()
    value[7] = value[7].lower()
    value[8] = value[8].lower()
    value[9] = value[9].lower()

print(info)
print(data_json)

print('\n')

if info == data_json:
  print('The code is okay')
else:
  print('There is an error with the code')
# Out:
# {'E9559': ['female', 40, 24.0, 0.96, 105, 115.0, 34.9, 'alert', 'air', 'unrestricted normal activity', 0.15, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E9385': ['female', 51, 19.0, 0.99, 90, 91.0, 38.1, 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.18, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E3067': ['female', 40, 29.0, 0.96, 105, 95.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.18, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E9422': ['female', 66, 19.0, 0.96, 135, 115.0, 38.1, 'alert', 'air', 'bed/chair bound, no self-care', 0.34, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E8661': ['male', 18, 22.0, 0.95, 105, 115.0, 36.3, 'confused or not alert', 'air', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E6235': ['male', 16, 23.0, 0.96, 135, 115.0, 39.2, 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.29, 'Childrens Healthcare of Atlanta at Scottish Rite', '1001 JOHNSON FERRY RD'], 'E4451': ['male', 40, 8.0, 0.96, 135, 115.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E8433': ['female', 40, 23.0, 0.99, 89, 91.0, 38.1, 'alert', 'air', 'limited self-care', 0.22, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E7593': ['female', 80, 23.0, 0.96, 105, 115.0, 38.1, 'alert', 'supplemental oxygen', 'limited activity, can self-care', 0.34, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E3296': ['male', 51, 23.0, 0.95, 105, 115.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E4157': ['female', 40, 23.0, 0.96, 41, 115.0, 35.4, 'alert', 'air', 'unrestricted normal activity', 0.03, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E7702': ['female', 40, 22.0, 0.96, 105, 115.0, 38.1, 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.15, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], '
 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E3447': ['male', 80, 22.0, 0.96, 41, 115.0, 38.1, 'alert', 'air', 'limited activity, can self-care', 0.29, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E8208': ['female', 18, 23.0, 0.96, 135, 115.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.15, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E4428': ['female', 40, 23.0, 0.96, 38, 115.0, 36.3, 'alert', 'air', 'unrestricted normal activity', 0.09, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTO ...
# {'E9559': ['female', 40, 24.0, 0.96, 105.0, 115.0, 34.9, 'alert', 'air', 'unrestricted normal activity', 0.15, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E9385': ['female', 51, 19.0, 0.99, 90.0, 91.0, 38.1, 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.18, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E3067': ['female', 40, 29.0, 0.96, 105.0, 95.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.18, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E9422': ['female', 66, 19.0, 0.96, 135.0, 115.0, 38.1, 'alert', 'air', 'bed/chair bound, no self-care', 0.34, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E8661': ['male', 18, 22.0, 0.95, 105.0, 115.0, 36.3, 'confused or not alert', 'air', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E6235': ['male', 16, 23.0, 0.96, 135.0, 115.0, 39.2, 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.29, 'Childrens Healthcare of Atlanta at Scottish Rite', '1001 JOHNSON FERRY RD'], 'E4451': ['male', 40, 8.0, 0.96, 135.0, 115.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E8433': ['female', 40, 23.0, 0.99, 89.0, 91.0, 38.1, 'alert', 'air', 'limited self-care', 0.22, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E7593': ['female', 80, 23.0, 0.96, 105.0, 115.0, 38.1, 'alert', 'supplemental oxygen', 'limited activity, can self-care', 0.34, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E3296': ['male', 51, 23.0, 0.95, 105.0, 115.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E4157': ['female', 40, 23.0, 0.96, 41.0, 115.0, 35.4, 'alert', 'air', 'unrestricted normal activity', 0.03, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E7702': ['female', 40, 22.0, 0.96, 105.0, 115.0, 38.1, 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.15, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E8158': ['male', 40, 20.0, 0.99, 135.0, 115.0, 39.2, 'alert', 'air', 'unrestricted normal activity', 0.15, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E4795': ['female', 80, 11.0, 0.93, 105.0, 95.0, 40.8, 'alert', 'air', 'limited activity, can self-care', 0.46, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E8800': ['male', 80, 22.0, 0.96, 105.0, 115.0, 39.2, 'confused or not alert', 'air', 'limited activity, can self-care', 0.47, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E4855': ['female', 51, 23.0, 0.94, 135.0, 115.0, 38.1, 'alert', 'air', 'limited strenuous activity, can do light activity', 0.29, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E9691': ['male', 16, 10.0, 0.96, 105.0, 115.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.03, 'Childrens Healthcare of Atlanta at Scottish Rite', '1001 JOHNSON FERRY RD'], 'E4535': ['female', 19, 11.0, 0.99, 105.0, 115.0, 35.4, 'alert', 'air', 'unrestricted normal activity', 0.02, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E2360': ['male', 40, 20.0, 0.96, 51.0, 95.0, 34.9, 'alert', 'supplemental oxygen', 'unrestricted normal activity', 0.22, 'Southwest Hospital and Medical Center', '501 FAIRBURN ROAD SW'], 'E3447': ['male', 80, 22.0, 0.96, 41.0, 115.0, 38.1, 'alert', 'air', 'limited activity, can self-care', 0.29, 'Wesley Woods Geriatric Hospital', '1821 CLIFTON ROAD, NE'], 'E8208': ['female', 18, 23.0, 0.96, 135.0, 115.0, 38.1, 'alert', 'air', 'unrestricted normal activity', 0.15, 'Select Specialty Hospital - Northeast Atlanta', '1821 CLIFTON ROAD NE'], 'E4428': ['female', 40, 23.0, 0.96, 38.0, 115.0, 36.3, 'alert', 'air', 'unrestricted normal activity', 0.09, 'Select Specialty ...
#
#
# The code is okay

# %% [markdown]
# ---
#
# ## Check your work above
#
# If you didn't get them all correct, take a few minutes to think through those that aren't correct.
#
#
# ## Submitting Your Work
#
# Submit your work as usual into a folder named `midterm`

# %% [markdown]
# ---
